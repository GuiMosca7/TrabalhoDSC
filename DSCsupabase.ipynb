# %% [markdown]
# **MINHA REDE SOCIAL**
#
# Uma rede social feita em python, com o supabase (postgres).

# %%
#estamos "abrindo o terminal" e baixando a lib
# !pip install supabase
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.0/78.0 kB 2.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.1/164.1 kB 10.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 3.3 MB/s eta 0:00:00
# ...

# %%
#importando lib
from supabase import create_client, Client

supabase: Client = create_client(
    'https://dddxujlkfvticyrwscil.supabase.co',
    'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImRkZHh1amxrZnZ0aWN5cndzY2lsIiwicm9sZSI6ImFub24iLCJpYXQiOjE3MTYyOTY1NzMsImV4cCI6MjAzMTg3MjU3M30.dp6zngvbuZ3hqkLjPV_ULdDISItX4UJ9RY9SmZnECUw'
    )

# %%
#pegando todos os dados da tabela bento_alunos

response = supabase.table("bento_alunos").select("*").execute()

print(response)
# Out:
# data=[{'id': '8a93ef72-08ed-490d-8609-884ec7b7985e', 'user_name': 'douglas', 'name': 'douglas caramelo da silva', 'password': 'douglas1'}, {'id': 'ab7e07c1-76e6-49e5-bb71-869134821ad2', 'user_name': 'dominic', 'name': 'dominic torresmo', 'password': 'familia1'}, {'id': '04b501b8-9f55-4513-a18b-9c7a57c670f1', 'user_name': 'rico999887', 'name': 'Enrico Bornelli', 'password': '12345   '}] count=None
# data=[{'id': '8a93ef72-08ed-490d-8609-884ec7b7985e', 'user_name': 'douglas', 'name': 'douglas caramelo da silva', 'password': 'douglas1'}, {'id': 'ab7e07c1-76e6-49e5-bb71-869134821ad2', 'user_name': 'dominic', 'name': 'dominic torresmo', 'password': 'familia1'}, {'id': '04b501b8-9f55-4513-a18b-9c7a57c670f1', 'user_name': 'rico999887', 'name': 'Enrico Bornelli', 'password': '12345   '}] count=None

# %%
#pegando apenas o dado "nome" de bento_alunos

for i in response.data:
  print(i['user_name'])
# Out:
# douglas
# dominic
# rico999887

# %%
#pegando todos os dados da tabela aluno_posts

responsee = supabase.table("aluno_posts").select("*").execute()

print(responsee)
# Out:
# data=[{'id': '611c45ce-4028-474e-8dd1-d52838bc0541', 'content': 'eu sou o douglas', 'bento_aluno_id': '8a93ef72-08ed-490d-8609-884ec7b7985e'}, {'id': '64b390ac-1268-4063-a2dd-a738b7da1c31', 'content': 'eu não tenho amigos, tenho família', 'bento_aluno_id': 'ab7e07c1-76e6-49e5-bb71-869134821ad2'}] count=None

# %%
#pegando apenas o dado "content" de aluno_posts

for i in responsee.data:
  print(i['content'])
# Out:
# eu sou o douglas
# eu não tenho amigos, tenho família

# %%
def showMenu():
  print("1 - Cadastrar")
  print("2 - Login")
  print("3 - Sair")
  option = int(input("Escolha uma opção: "))
  if option == 1:
    print("Cadastro")
  if option == 2:
    print("Login")
    email = input("Insira o Nome do Usuário: ")
    senha = input("Insira a Senha: ")
    for i in responsee.data:
      print(i['content'])
  if option == 3:
    print("Sair")
  if option > 3:
    print("Opção inválida, tente novamente")
  return
  print("Opção inválida")

# %%
showMenu()
# Out:
# 1 - Cadastrar
# 2 - Login
# 3 - Sair
# Escolha uma opção: 2
# Login
# Insira o Nome do Usuário: ghdf
# Insira a Senha: gsd
# eu sou o douglas
# eu não tenho amigos, tenho família

# %%
import os
